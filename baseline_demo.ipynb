# %% [markdown]
# # LEGO ABSA

# %%
from lego_absa.train import lego_absa_train

save_path = "outputs/models/lego_absa/model.pt"
json_path = "hotel_dataset/eng/hotel_aste_train_augmented_noreasoning.json"
model_name = "Qwen/Qwen2.5-0.5B"
device = "cuda"

lego_absa_model = lego_absa_train(
    model_name=model_name,
    dataset_path=json_path,
    num_epochs=30,
    batch_size=16,
    lr=3e-4,
    device="cuda",
    save_path=save_path,
    seed=42,
    order_list=["a", "o", "oa", "as"]
)

# %% [markdown]
# # Zhang GAS

# %%
from zhang_gas.train import zhang_gas_train

save_path = "outputs/models/zhang_gas/model.pt"
json_path = "hotel_dataset/eng/hotel_aste_train_augmented_noreasoning.json"
model_name = "Qwen/Qwen2.5-0.5B"
device = "cuda"

lego_absa_model = zhang_gas_train(
    model_name=model_name,
    dataset_path=json_path,
    num_epochs=30,
    batch_size=16,
    lr=3e-4,
    device="cuda",
    save_path=save_path,
    seed=42,
)
